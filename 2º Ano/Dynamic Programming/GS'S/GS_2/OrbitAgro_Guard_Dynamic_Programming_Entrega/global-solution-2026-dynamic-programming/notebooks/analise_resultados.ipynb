# %% [markdown]
# # OrbitAgro Guard - Analise de Resultados
#
# Notebook de apoio para executar a analise de Dynamic Programming.

# %%
from src.run_analysis import main
main()

# %% [markdown]
# As figuras obrigatorias sao geradas em `figures/` e as metricas em `results/`.
